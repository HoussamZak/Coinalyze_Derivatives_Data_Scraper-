# %%
#Modules & Libraries
import pandas as pd
import os 
import csv

# %%
#Iteration through the CSV files gathered on deepnote.com since September 1st 2022

directory = 'Data'
for filename in os.listdir(directory):
    f = os.path.join(directory, filename)
    # if os.path.isfile(f):
    df = pd.read_csv(f)
    print(df)
# Out:
#      Unnamed: 0                       Coin       Price Change 24H Vol. 24H  \
# 0             0               Ethereum-ETH   $1,546.77     -1.85%   $36.2b
# 1             1                Bitcoin-BTC  $19,916.32     -1.49%   $27.7b
# 2             2       Ethereum Classic-ETC      $32.02     -2.34%    $1.5b
# 3             3                 Solana-SOL      $31.08     -3.58%    $1.2b
# 4             4                 Tellor-TRB      $19.24    -15.21%    $1.2b
# ..          ...                        ...         ...        ...      ...
# 246         246                 Mango-MNGO     $0.0443     -0.39%   $40.9k
# 247         247              ETHPOW-ETHPOW         NaN        NaN   $36.7k
# 248         248  Uniswap Index FTX-UNISWAP  $15,925.00     -1.39%   $31.9k
# 249         249                    ASD-ASD     $0.0804     +0.24%   $31.6k
# 250         250          Step Finance-STEP     $0.0358     -0.19%   $24.5k
#
# ...

# %%
print(df.T)
# Out:
#                               0            1                     2    \
# Unnamed: 0                      0            1                     2
# Coin                 Ethereum-ETH  Bitcoin-BTC  Ethereum Classic-ETC
# Price                   $1,633.44   $19,281.84                $36.65
# Change 24H                 +3.88%       +1.15%                +2.71%
# Vol. 24H                   $39.2b       $27.1b                 $4.1b
# Open Interest               $7.3b        $9.6b               $493.4m
# OI Change 24H              +3.22%       -1.90%                +0.23%
# OI Share                   30.78%       40.74%                 2.09%
# OI / VOL24H                  0.19         0.36                  0.12
# Funding (avg)            -0.0063%     +0.0023%              -0.0045%
# Pred. Funding (avg)      -0.0067%     +0.0032%              -0.0032%
# Liqs. 24H                  $88.1m       $28.7m                $11.7m
#
#                           3           4           5            6    \
# ...

# %%
btc_futures_data = pd.DataFrame()
for filename in os.listdir(directory):
    reader_obj = csv.DictReader(filename)
    for row in reader_obj:
        print(row)
    
    
    # btc_futures_data.append(row[0])
# Out:
# {'c': 'r'}
# {'c': 'y'}
# {'c': 'p'}
# {'c': 't'}
# {'c': 'o'}
# {'c': '_'}
# {'c': 'f'}
# {'c': 'u'}
# {'c': 't'}
# {'c': 'u'}
# {'c': 'r'}
# {'c': 'e'}
# {'c': 's'}
# {'c': '_'}
# {'c': 'd'}
# {'c': 'a'}
# {'c': 't'}
# {'c': 'a'}
# {'c': '_'}
# {'c': '2'}
# {'c': '0'}
# {'c': '2'}
# {'c': '2'}
# {'c': '-'}
# {'c': '0'}
# {'c': '9'}
# {'c': '-'}
# {'c': '0'}
# {'c': '1'}
# {'c': ' '}
# {'c': '0'}
# {'c': '9'}
# {'c': '4'}
# {'c': '6'}
# {'c': '1'}
# {'c': '3'}
# {'c': '.'}
# {'c': 'c'}
# {'c': 's'}
# {'c': 'v'}
# {'c': 'r'}
# {'c': 'y'}
# {'c': 'p'}
# {'c': 't'}
# {'c': 'o'}
# {'c': '_'}
# {'c': 'f'}
# {'c': 'u'}
# {'c': 't'}
# {'c': 'u'}
# {'c': 'r'}
# {'c': 'e'}
# {'c': 's'}
# {'c': '_'}
# {'c': 'd'}
# {'c': 'a'}
# {'c': 't'}
# {'c': 'a'}
# {'c': '_'}
# {'c': '2'}
# {'c': '0'}
# {'c': '2'}
# {'c': '2'}
# {'c': '-'}
# {'c': '0'}
# {'c': '9'}
# {'c': '-'}
# {'c': '0'}
# {'c': '1'}
# {'c': ' '}
# {'c': '1'}
# {'c': '0'}
# {'c': '4'}
# {'c': '6'}
# {'c': '2'}
# {'c': '7'}
# ...
